# %% [markdown]
# # Analisis Dendograma

# %% [markdown]
# ## Librerías a Utilizar

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
import os

# %% [markdown]
# ## Dendogramas

# %% [markdown]
# ### Healthy Bar

# %%
import scipy.cluster.hierarchy as shc

hb = pd.read_csv('/home/bryan/Escritorio/Paper/Prueba1/HB.csv').iloc[:,1:]

# %%
hb = hb.transpose()
hb.head()
# Out:
#        0         1         2         3         4         5         6        \
# -X1-  0.000213  0.000192  0.000175  0.000185  0.000185  0.000187  0.000106
# -Y1-  0.000274  0.000265  0.000227  0.000281  0.000275  0.000296  0.000244
# -Z1-  0.000279  0.000262  0.000212  0.000237  0.000246  0.000241  0.000210
# -X2-  0.000146  0.000148  0.000202  0.000158  0.000178  0.000147  0.000159
# -Y2-  0.000231  0.000194  0.000195  0.000218  0.000225  0.000220  0.000198
#
#        7         8         9        ...   3963870   3963871   3963872  \
# -X1-  0.000200  0.000191  0.000099  ...  0.000473  0.000028  0.000135
# -Y1-  0.000301  0.000249  0.000237  ...  0.000661 -0.000004  0.000379
# -Z1-  0.000243  0.000223  0.000230  ...  0.000347 -0.000104  0.000567
# -X2-  0.000165  0.000132  0.000104  ...  0.000009  0.000030  0.000175
# -Y2-  0.000224  0.000204  0.000154  ...  0.000216  0.000136  0.000138
#
#        3963873   3963874   3963875   3963876   3963877   3963878   3963879
# ...

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
#sample1 = hb.sample(n = 10000)
#sample1.head()

# %%
Z = linkage(hb, 'ward')

# %%
plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')
#plt.savefig('HB.jpg')

# %% [markdown]
# ### Replica Bar

# %%
hb = pd.read_csv('/home/bryan/Escritorio/Paper/Prueba1/RB.csv').iloc[:,1:]
hb = hb.transpose()
hb.head()
# Out:
#        0         1         2         3         4         5         6        \
# -X1-  0.000164  0.000232  0.000194  0.000172  0.000186  0.000159  0.000199
# -Y1-  0.000302  0.000290  0.000269  0.000289  0.000239  0.000297  0.000293
# -Z1-  0.000252  0.000254  0.000284  0.000280  0.000211  0.000251  0.000254
# -X2-  0.000152  0.000156  0.000142  0.000143  0.000157  0.000146  0.000132
# -Y2-  0.000214  0.000203  0.000174  0.000232  0.000213  0.000167  0.000236
#
#        7         8         9        ...   1981930   1981931   1981932  \
# -X1-  0.000168  0.000143  0.000197  ...  0.000125  0.000077  0.000164
# -Y1-  0.000272  0.000278  0.000265  ...  0.000427  0.000078  0.000237
# -Z1-  0.000217  0.000234  0.000262  ...  0.000121  0.000246  0.000362
# -X2-  0.000133  0.000161  0.000118  ...  0.000319 -0.000047  0.000374
# -Y2-  0.000224  0.000248  0.000218  ...  0.000266  0.000113  0.000103
#
#        1981933   1981934   1981935       1981936   1981937   1981938   1981939
# ...

# %%
Z = linkage(hb, 'ward')
plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')

# %% [markdown]
# ### Crack Damaged

# %%
hb = pd.read_csv('/home/bryan/Escritorio/Paper/Prueba1/CDB.csv').iloc[:,1:]
hb = hb.transpose()
hb.head()
# Out:
#        0         1         2         3         4         5         6        \
# -X1-  0.000139  0.000073  0.000156  0.000127  0.000132  0.000132  0.000109
# -Y1-  0.000280  0.000210  0.000224  0.000241  0.000237  0.000266  0.000249
# -Z1-  0.000215  0.000120  0.000180  0.000165  0.000158  0.000155  0.000205
# -X2-  0.000189  0.000143  0.000143  0.000119  0.000175  0.000158  0.000147
# -Y2-  0.000235  0.000209  0.000239  0.000230  0.000197  0.000255  0.000216
#
#        7         8         9        ...   1981930   1981931   1981932  \
# -X1-  0.000151  0.000127  0.000099  ...  0.000041  0.000075 -0.000079
# -Y1-  0.000163  0.000237  0.000179  ...  0.000002  0.000354  0.000157
# -Z1-  0.000121  0.000136  0.000118  ...  0.000502  0.000197 -0.000056
# -X2-  0.000163  0.000177  0.000121  ...  0.000021  0.000123  0.000183
# -Y2-  0.000213  0.000202  0.000197  ...  0.000202  0.000080  0.000304
#
#        1981933   1981934   1981935   1981936   1981937   1981938   1981939
# ...

# %%
Z = linkage(hb, 'ward')
plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')

# %% [markdown]
# ### Unlocked Bolt

# %%
hb = pd.read_csv('/home/bryan/Escritorio/Paper/Prueba1/UB.csv').iloc[:,1:]
hb = hb.transpose()
hb.head()
# Out:
#        0         1         2         3         4         5         6        \
# -X1-  0.000168  0.000122  0.000099  0.000150  0.000194  0.000156  0.000150
# -Y1-  0.000204  0.000277  0.000214  0.000258  0.000244  0.000287  0.000230
# -Z1-  0.000213  0.000213  0.000128  0.000209  0.000194  0.000188  0.000198
# -X2-  0.000135  0.000180  0.000153  0.000163  0.000201  0.000119  0.000239
# -Y2-  0.000201  0.000230  0.000217  0.000213  0.000202  0.000234  0.000247
#
#        7         8         9        ...   1981930   1981931   1981932  \
# -X1-  0.000130  0.000132  0.000166  ...  0.000134  0.000241  0.000136
# -Y1-  0.000230  0.000301  0.000247  ...  0.000355  0.000370  0.000179
# -Z1-  0.000207  0.000208  0.000194  ...  0.000336 -0.000032  0.000202
# -X2-  0.000116  0.000207  0.000151  ...  0.000166  0.000143  0.000073
# -Y2-  0.000212  0.000252  0.000232  ...  0.000363  0.000185  0.000198
#
#        1981933   1981934   1981935   1981936   1981937   1981938   1981939
# ...

# %%
Z = linkage(hb, 'ward')
plt.figure(figsize=(15, 5))
dn = dendrogram(Z, labels = hb.index ,orientation='right')
